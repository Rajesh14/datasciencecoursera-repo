# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajesh14/datasciencecoursera-repo/blob/master/Copy_of_B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
dataset= pd.read_csv('/content/drive/My Drive/colab/Covert_new0213.csv')
dataset.head()
#from imblearn.over_sampling import RandomOverSampler
#from collections import Counter

#Splitting X and y
#X = dataset.drop('ASCII Code', axis =1)
#y = dataset['Binary Signal']

# Apply Random Oversampling
#Oversampler = RandomOverSampler(sampling_strategy='auto',random_state=42)
#X_resample, y_resample = Oversampler.fit_resample(X, y)


#print('Original dataset shape %s' % Counter(y))
#print('Resampled dataset shape %s' % Counter(y_resample))
# Out:
# Mounted at /content/drive
#    ASCII Code  Binary Signal
# 0       64428              1
# 1       32714              0
# 2       75036              1
# 3       16234              0
# 4       76468              0

# %%
dataset['Binary Signal'].value_counts()
# Out:
# Binary Signal
# 0    5008
# 1    4992
# Name: count, dtype: int64

# %%
X =dataset[['ASCII Code']]
X.head()
# Out:
#    ASCII Code
# 0       64428
# 1       32714
# 2       75036
# 3       16234
# 4       76468

# %%
y = dataset['Binary Signal']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Binary Signal, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification

#Create an imbalanced dataset
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, weights=[0.9, 0.1])

# Apply SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,test_size=0.3, random_state=42)
from sklearn.linear_model import LogisticRegression # Import a model

model = LogisticRegression() # Create a LogisticRegression model
model.fit(X_train, y_train) # Train the model with your training data

predictions = model.predict(X_test) # Now you can use the trained model to make predictions

# %%
from sklearn.preprocessing import StandardScaler

ss_train = StandardScaler()
X_train = ss_train.fit_transform(X_train)

ss_test = StandardScaler()
X_test = ss_test.fit_transform(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, predictions)

TN, FP, FN, TP = confusion_matrix(y_test, predictions).ravel()

print('True Positive(TP)  = ', TP)
print('False Positive(FP) = ', FP)
print('True Negative(TN)  = ', TN)
print('False Negative(FN) = ', FN)
# Out:
# True Positive(TP)  =  264
# False Positive(FP) =  8
# True Negative(TN)  =  260
# False Negative(FN) =  7

# %%
accuracy =  (TP + TN) / (TP + FP + TN + FN)

print('Accuracy of the binary classifier = {:0.3f}'.format(accuracy))
# Out:
# Accuracy of the binary classifier = 0.972

# %%
models = {}
from sklearn.metrics import roc_auc_score, cohen_kappa_score, matthews_corrcoef # Import roc_auc_score,cohen_kappa_score and matthews_corrcoef
y_pred_proba = model.predict_proba(X_test)[:,1]
y_pred=predictions
# Logistic Regression
from sklearn.linear_model import LogisticRegression
models['Logistic Regression'] = LogisticRegression()
# Calculate AUC
auc = roc_auc_score(y_test, y_pred_proba)
#print(f'AUC: {auc:.2f}')

# Calculate Kappa
kappa = cohen_kappa_score(y_test, y_pred)
#print(f'Kappa: {kappa:.2f}')

# Calculate MCC
mcc = matthews_corrcoef(y_test, y_pred)
#print(f'MCC: {mcc:.2f}')



# Support Vector Machines
from sklearn.svm import LinearSVC
models['Support Vector Machines'] = LinearSVC()

# Calculate AUC
auc = roc_auc_score(y_test, y_pred_proba)
#print(f'AUC: {auc:.2f}')

# Calculate Kappa
kappa = cohen_kappa_score(y_test, y_pred)
#print(f'Kappa: {kappa:.2f}')

# Calculate MCC
mcc = matthews_corrcoef(y_test, y_pred)
#print(f'MCC: {mcc:.2f}')

# Decision Trees
from sklearn.tree import DecisionTreeClassifier
models['Decision Trees'] = DecisionTreeClassifier()

# Calculate AUC
auc = roc_auc_score(y_test, y_pred_proba)
#print(f'AUC: {auc:.2f}')

# Calculate Kappa
kappa = cohen_kappa_score(y_test, y_pred)
#print(f'Kappa: {kappa:.2f}')

# Calculate MCC
mcc = matthews_corrcoef(y_test, y_pred)
#print(f'MCC: {mcc:.2f}')

# Random Forest
from sklearn.ensemble import RandomForestClassifier
models['Random Forest'] = RandomForestClassifier()

# Calculate AUC
auc = roc_auc_score(y_test, y_pred_proba)
#print(f'AUC: {auc:.2f}')

# Calculate Kappa
kappa = cohen_kappa_score(y_test, y_pred)
#print(f'Kappa: {kappa:.2f}')

# Calculate MCC
mcc = matthews_corrcoef(y_test, y_pred)
print(f'MCC: {mcc:.2f}')

# Naive Bayes
from sklearn.naive_bayes import GaussianNB
models['Naive Bayes'] = GaussianNB()

# Calculate AUC
auc = roc_auc_score(y_test, y_pred_proba)
#print(f'AUC: {auc:.2f}')

# Calculate Kappa
kappa = cohen_kappa_score(y_test, y_pred)
#print(f'Kappa: {kappa:.2f}')

# Calculate MCC
mcc = matthews_corrcoef(y_test, y_pred)
#print(f'MCC: {mcc:.2f}')

# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
models['K-Nearest Neighbor'] = KNeighborsClassifier()

# Calculate AUC
auc = roc_auc_score(y_test, y_pred_proba)
#print(f'AUC: {auc:.2f}')

# Calculate Kappa
kappa = cohen_kappa_score(y_test, y_pred)
#print(f'Kappa: {kappa:.2f}')

# Calculate MCC
mcc = matthews_corrcoef(y_test, y_pred)
#print(f'MCC: {mcc:.2f}')
# Out:
# MCC: 0.94

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy, precision, recall = {}, {}, {}

for key in models.keys():

    # Fit the classifier
    models[key].fit(X_train, y_train)

    # Make predictions
    predictions = models[key].predict(X_test)

    # Calculate metrics
    accuracy[key] = accuracy_score(predictions, y_test)
    precision[key] = precision_score(predictions, y_test)
    recall[key] = recall_score(predictions, y_test)

# %%
import pandas as pd

df_model = pd.DataFrame(index=models.keys(), columns=['Accuracy', 'Precision', 'Recall'])
df_model['Accuracy'] = accuracy.values()
df_model['Precision'] = precision.values()
df_model['Recall'] = recall.values()
df_model['AUC'] = auc
df_model['Kappa'] = kappa
df_model['MCC'] = mcc

df_model
# Out:
#                          Accuracy  Precision    Recall       AUC     Kappa  \
# Logistic Regression      0.970315   0.970480  0.970480  0.994066  0.944338
# Support Vector Machines  0.974026   0.974170  0.974170  0.994066  0.944338
# Decision Trees           0.966605   0.955720  0.977358  0.994066  0.944338
# Random Forest            0.985158   0.981550  0.988848  0.994066  0.944338
# Naive Bayes              0.959184   0.922509  0.996016  0.994066  0.944338
# K-Nearest Neighbor       0.929499   0.996310  0.879479  0.994066  0.944338
#
#                               MCC
# Logistic Regression      0.944345
# Support Vector Machines  0.944345
# Decision Trees           0.944345
# Random Forest            0.944345
# Naive Bayes              0.944345
# K-Nearest Neighbor       0.944345
